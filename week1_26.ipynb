# %% [markdown]
# <a href="https://colab.research.google.com/github/sirfara12/PCVK25_3G_26/blob/main/week1_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %%
#membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://avatars.githubusercontent.com/u/98369663?v=4"]
#baca dan tampilkan image
#loop pada tiap url image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print()
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
#membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://avatars.githubusercontent.com/u/143992594?v=4"]
#baca dan tampilkan image
#loop pada tiap url image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print()
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  230  x  230
# <PIL.Image.Image image mode=RGB size=230x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for y in range(lebar):
    image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# PERTANYAAN PRAKTIKUM D2
#
#
#
# 1.   Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# jawab: Karena Google Colab berbasis cloud, tidak perlu instalasi, mendukung GPU/TPU gratis, terintegrasi dengan Google Drive & GitHub, serta sudah menyediakan banyak library (seperti NumPy, OpenCV, Matplotlib) sehingga praktikum lebih mudah dan bisa dijalankan di berbagai perangkat tanpa kendala spesifikasi.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
# jawab: • NumPy untuk manipulasi array numerik.
# • OpenCV untuk pengolahan citra, deteksi objek, dan tracking.
# • Matplotlib dan Seaborn untuk visualisasi data dan citra.
# • scikit-image untuk pemrosesan citra tingkat lanjut (filtering, edge detection,
# transformasi morfologi).
# • TensorFlow dan PyTorch untuk deep learning yang digunakan dalam
# pengembangan model klasifikasi dan deteksi citra. Yang ada dipraktikum ini hanya NumPy dan OpenCV.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :  Image: cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?
# jawab; kode tersebut digunakan untuk mengecilkan ukuran citra 50% dari ukuran asli. Jika dilakukan citra lebih ringan diproses & ditampilkan.Jika tidak dilakukan citra tetap besar, mungkin lebih berat diproses, terutama jika resolusinya tinggi.
#
# 4. Perhatikan potongan kode progam berikut :
#    membuat garis horizontal ditengah image
#     for y in range (lebar):
#     image_3[int((tinggi)/2),y] = [255,255,255]
#  Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# jawab: kegunaan kode tersebut untuk pada perulangan menggambar garis
# [255,255,255] merepresentasikan warna putih dalam format RGB.
# Kode tersebut mengganti nilai piksel di tengah gambar menjadi putih, sehingga terbentuk garis horizontal berwarna putih.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# jawab: a. Keterkaitan pixel dengan resolusi gambar
# b. Pixel = elemen terkecil citra.
# c. Resolusi tinggi = jumlah pixel banyak,gambar lebih detail dan tajam.
# d. Resolusi rendah = jumlah pixel sedikit, gambar terlihat buram/pecah jika diperbesar.

# %% [markdown]
# ### TUGAS PRAKTIKUM D2

# %%
# 1. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal di tengah
for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

# Gabungkan citra sebelum dan sesudah
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


# Membuat garis diagonal dari kiri atas ke kanan bawah
for i in range(min(tinggi, lebar)):
    image_3[i, i] = [255, 255, 255]

# Membuat garis diagonal dari kanan atas ke kiri bawah
for i in range(min(tinggi, lebar)):
    image_3[i, lebar - i - 1] = [255, 255, 255]

# Gabungkan citra sebelum dan sesudah
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)   # gambar asli
image_horizontal = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # copy utk digaris

# Titik tengah vertikal (tinggi)
y_tengah = int(tinggi/2)
panjang = 200

# Koordinat awal dan akhir di sumbu X
x_awal = int((lebar - panjang) / 2)
x_akhir = x_awal + panjang

# Buat garis horizontal putih
for x in range(x_awal, x_akhir):
    image_horizontal[y_tengah, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_horizontal))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %%
# 4.

# Konversi ke RGB
image_kotak = cv.cvtColor(image, cv.COLOR_BGR2RGB)

x_awal, y_awal = 50, 80
x_akhir, y_akhir = x_awal + 100, y_awal + 100

for y in range(y_awal, y_akhir):
    for x in range(x_awal, x_akhir):
        image_kotak[y, x] = [255, 255, 255]

image_asli = cv.cvtColor(image, cv.COLOR_BGR2RGB)
final_frame = cv.hconcat((image_asli, image_kotak))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>
