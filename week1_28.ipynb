# %% [markdown]
# <a href="https://colab.research.google.com/github/sirfara12/PCVK_GANJIL_25-26/blob/main/week1_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# Membuat list untuk menyimpan url dari beberapa image
urls = [
    "https://avatars.githubusercontent.com/u/143992594?s=400&u=3596a71b223c87b9dd9036f0ee3bdd8573744874&v=4",
    "https://avatars.githubusercontent.com/u/143992594?s=400&u=3596a71b223c87b9dd9036f0ee3bdd8573744874&v=4",
    "https://avatars.githubusercontent.com/u/143992594?s=400&u=3596a71b223c87b9dd9036f0ee3bdd8573744874&v=4"
]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
    image = io.imread(url)                              # read image
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)     # resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)      # convert color to RGB
    final_frame = cv.hconcat([image, image_2])          # concatenate image
    cv2_imshow(final_frame)                             # show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
# <PIL.Image.Image image mode=RGB size=400x200>
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
tinggi = image_2.shape[0]   # jumlah pixel vertikal
lebar = image_2.shape[1]    # jumlah pixel horizontal
print("resolusi image: tinggi x lebar = ", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  200 x 200
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
for y in range(lebar):
    image_3[tinggi // 2, y] = 255

final_frame = cv.hconcat([image_2, cv.cvtColor(image_3, cv.COLOR_GRAY2BGR)])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
