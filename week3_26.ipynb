# %% [markdown]
# <a href="https://colab.research.google.com/github/sirfara12/PCVK25_3G_26/blob/main/week3_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **D. PRAKTIKUM**
# ### D1. Operasi Citra Sederhana
# #### Transformasi Linier Brightness
# formula : *g(𝑥,𝑦) = 𝑓(𝑥,𝑦) +b* <br>
#  g(x,y) adalah nilai pixel setelah transformasi, f(x,y) adalah nilai pixel asli, dan b
# adalah nilai brightness.

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow

print(' Mengubah tingkat kecerahan citra ')
print('----------------------------------')
try:
    brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
    print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

# akses per piksel
for y in range(original.shape[0]):
    for x in range(original.shape[1]):
        for c in range(original.shape[2]):
            brightness_image[y, x, c] = np.clip(original[y, x, c] + brightness, 0, 255)


final_frame = cv.hconcat([original, brightness_image])
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
# ----------------------------------
# Masukkan nilai kecerahan: 50
# /tmp/ipython-input-2121598996.py:19: RuntimeWarning: overflow encountered in scalar add
#   brightness_image[y, x, c] = np.clip(original[y, x, c] + brightness, 0, 255)
# <PIL.Image.Image image mode=RGB size=512x256>

# %% [markdown]
# ### **TUGAS PRAKTIKUM D1**
#
#
# 1.    Implementasikan inverse citra pada Google Colaboratory menggunakan formula yang terdapat pada bagian Ulasan Teori, sehingga menghasilkan keluaran seperti berikut:  *Gunakan Gambar KTM

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/KTM lama.jpg')

# Inverse citra: g(x) = 255 - f(x)
inverse = 255 - img

plt.subplot(1,2,1); plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB)); plt.title("Asli"); plt.axis("off")
plt.subplot(1,2,2); plt.imshow(cv.cvtColor(inverse, cv.COLOR_BGR2RGB)); plt.title("Inverse"); plt.axis("off")
plt.show()

# %% [markdown]
# 2.   Implementasikan transformasi contrast pada Google Colaboratory menggunakan
# formula yang terdapat pada bagian Ulasan Teori untuk kontras, sehingga
# menghasilkan keluaran seperti berikut:

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow
print('Mengubah tingkat kecerahan citra')
print('--------------------------------')
try:
  brightness = float(input('Masukkan nilai kecerahan: '))
  contrast = float(input('Masukkan nilai kontras: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness * contrast, 0, 255)

final_frame = cv.hconcat((original,brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukkan nilai kecerahan: 50
# Masukkan nilai kontras: 2
# <PIL.Image.Image image mode=RGB size=512x256>

# %% [markdown]
# 3.  Implementasikan transformasi logarithmic brightness pada Google Colaboratory
# menggunakan formula yang terdapat pada bagian Ulasan Teori untuk transformasi
# log, sehingga menghasilkan keluaran seperti berikut:

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

print('Mengubah tingkat kecerahan citra')
print('--------------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#Akses per piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(brightness*(np.log(1+original[y,x,c])),0,255)

final_frame = cv.hconcat((original,brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# Masukkan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=512x256>

# %% [markdown]
# 4. Implementasikan transformasi grayscale menggunakan metode averaging, lightness,
# dan luminance pada Google Colaboratory menggunakan formula yang terdapat pada
# bagian Ulasan Teori, sehingga menghasilkan keluaran seperti berikut:
# Gunakan Gambar KTM

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Baca gambar KTM
img = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/KTM lama.jpg')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

gray_avg = np.mean(img_rgb, axis=2).astype(np.uint8)

plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Asli (KTM)")

plt.subplot(1,2,2)
plt.imshow(gray_avg, cmap="gray")
plt.title("Grayscale - Averaging")
plt.show()


# Grayscale Lightness
gray_light = ((np.max(img_rgb, axis=2) + np.min(img_rgb, axis=2)) / 2).astype(np.uint8)

plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Asli (KTM)")

plt.subplot(1,2,2)
plt.imshow(gray_light, cmap="gray")
plt.title("Grayscale - Lightness")
plt.show()

# 3. Grayscale Luminance
gray_lumi = (0.21 * img_rgb[:,:,0] +
             0.72 * img_rgb[:,:,1] +
             0.07 * img_rgb[:,:,2]).astype(np.uint8)

plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Asli (KTM)")

plt.subplot(1,2,2)
plt.imshow(gray_lumi, cmap="gray")
plt.title("Grayscale - Luminance")
plt.show()

# %% [markdown]
# 5. Tampilkanlah warna tertentu pada citra, dan ubah warna lain menjadi grayscale. Misal,
# tampilkan warna biru pada citra masukan dan ubah bagian lain yang tidak berwarna
# biru menjadi grayscale seperti pada contoh berikut:

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('/content/drive/MyDrive/SEMESTER 5/PCVK/KTM lama.jpg')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)  # ubah BGR → RGB

# Ubah grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
gray_bgr = cv.cvtColor(gray, cv.COLOR_GRAY2BGR)

# Range warna biru dalam HSV
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
lower_blue = np.array([90, 80, 40])
upper_blue = np.array([130, 255, 255])

mask = cv.inRange(hsv, lower_blue, upper_blue)
result = np.where(mask[:, :, np.newaxis] != 0, img_rgb, gray_bgr)

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].imshow(img_rgb)
ax[1].imshow(result)
for a in ax:
    a.set_xticks([0, 200, 400, 600])
    a.set_yticks([0, 200, 400])

plt.tight_layout()
plt.show()
